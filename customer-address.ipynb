# %% [markdown]
# # Customer Address
#
# Below is the analysis of the Customer Address data. The analysis includes reviewing the data to clean and making necessary changes to increase reliability for analysis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /kaggle/input/kpmg-virtualinternship/KPMG (1).xlsx

# %%
RawData= pd.ExcelFile("/kaggle/input/kpmg-virtualinternship/KPMG (1).xlsx")

# %%
CustomerAddress = pd.read_excel (RawData,'CustomerAddress')

# %%
CustomerAddress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
CustomerAddress.isna().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
CustomerAddress.duplicated().sum()
# Out:
# 0

# %%
CustomerAddress.nunique()

# %%
CustomerAddress['state'].value_counts()
# Out:
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64

# %%
CustomerAddress['state']= CustomerAddress['state'].replace('New South Wales','NSW').replace('Victoria','VIC')

# %%
CustomerAddress['state'].value_counts()
# Out:
# NSW    2140
# VIC    1021
# QLD     838
# Name: state, dtype: int64

# %%
CustomerAddress['country'].value_counts()
# Out:
# Australia    3999
# Name: country, dtype: int64

# %%
CustomerAddress['property_valuation'].value_counts().sort_index()
# Out:
# 1     154
# 2     143
# 3     186
# 4     214
# 5     225
# 6     238
# 7     493
# 8     646
# 9     647
# 10    577
# 11    281
# 12    195
# Name: property_valuation, dtype: int64
